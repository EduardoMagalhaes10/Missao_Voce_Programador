# %% [markdown]
# <a href="https://colab.research.google.com/github/EduardoMagalhaes10/Missao_Voce_Programador/blob/main/Teste.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("Hello World")
# Out:
# Hello World
